# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/Siddharth/Downloads/archive (5)/diabetes.csv")

# %%
df.head(3)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1

# %%
def BMI_category(BMI):
    if BMI<18.5:
        return 'Underweight'
    elif 18.5 <=BMI< 25:
        return 'Normal'
    elif 25 <= BMI < 30:
        return 'Overweight'
    else:
        return 'Obese'

# %%
df['BMI_category'] = df['BMI'].apply(BMI_category)

# %%
df.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome BMI_category
# 0                     0.627   50        1        Obese
# 1                     0.351   31        0   Overweight
# 2                     0.672   32        1       Normal
# 3                     0.167   21        0   Overweight
# 4                     2.288   33        1        Obese

# %%
from sklearn.model_selection import train_test_split

# %%
train,val = train_test_split(df,test_size=0.2,random_state=20)

# %%
print(train.shape)
print(val.shape)
# Out:
# (614, 10)
# (154, 10)

# %%
from sklearn.preprocessing import StandardScaler,OneHotEncoder

# %%
encode = OneHotEncoder(sparse_output=False, drop='first')
scale = StandardScaler()

# %%
numeric_features = ['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age']
categorical_features = ['BMI_category']

# %%
train[numeric_features] = scale.fit_transform(train[numeric_features])
val[numeric_features] = scale.transform(val[numeric_features])

# %%
train
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 446    -0.844670 -0.652172       0.159016      -0.551331 -0.088078 -0.858281
# 260    -0.250595  2.233438      -0.055568      -0.360366  0.440046 -0.138690
# 570    -0.250595 -1.349793       0.051724      -1.315192 -0.704223  0.066907
# 590     2.125704 -0.303362       0.802767       1.231009 -0.704223  1.904434
# 30      0.343480 -0.366782       0.319953       0.339839 -0.704223  0.516651
# ..           ...       ...            ...            ...       ...       ...
# 218     0.343480 -1.127823       0.266307       0.085219 -0.704223 -0.382837
# 223     0.937554  0.679648      -0.484735       0.785424  0.968170 -0.408537
# 271    -0.547632 -0.398492      -0.377444       0.721769 -0.211307 -0.871131
# 474     0.046442 -0.208232      -0.270152      -1.315192 -0.704223 -0.395687
# 355     1.531629  1.408978       1.017350      -1.315192 -0.704223 -0.202940
#
#      DiabetesPedigreeFunction       Age  Outcome BMI_category
# 446                  0.536640 -0.431718        0   Overweight
# 260                 -0.533988  0.082657        0        Obese
# 570                 -0.620473  0.511303        0        Obese
# 590                  1.332900  1.025678        1        Obese
# 30                   0.202628  2.311616        0        Obese
# ..                        ...       ...      ...          ...
# 218                  2.224592 -0.088801        1   Overweight
# 223                  0.623125  2.397345        0   Overweight
# 271                 -1.043952 -1.031822        0   Overweight
# 474                 -1.049917 -0.774634        0   Overweight
# 355                 -0.525041  1.368595        1        Obese
#
# [614 rows x 10 columns]

# %%
encoded_train = encode.fit_transform(train[categorical_features])
encoded_val = encode.transform(val[categorical_features])

# %%
encoded_train_df = pd.DataFrame(encoded_train, columns=encode.get_feature_names_out(categorical_features), index=train.index)
encoded_val_df = pd.DataFrame(encoded_val, columns=encode.get_feature_names_out(categorical_features), index=val.index)

# %%
train = pd.concat([train.drop(columns=categorical_features), encoded_train_df], axis=1)
val = pd.concat([val.drop(columns=categorical_features), encoded_val_df], axis=1)

# %%
train
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 446    -0.844670 -0.652172       0.159016      -0.551331 -0.088078 -0.858281
# 260    -0.250595  2.233438      -0.055568      -0.360366  0.440046 -0.138690
# 570    -0.250595 -1.349793       0.051724      -1.315192 -0.704223  0.066907
# 590     2.125704 -0.303362       0.802767       1.231009 -0.704223  1.904434
# 30      0.343480 -0.366782       0.319953       0.339839 -0.704223  0.516651
# ..           ...       ...            ...            ...       ...       ...
# 218     0.343480 -1.127823       0.266307       0.085219 -0.704223 -0.382837
# 223     0.937554  0.679648      -0.484735       0.785424  0.968170 -0.408537
# 271    -0.547632 -0.398492      -0.377444       0.721769 -0.211307 -0.871131
# 474     0.046442 -0.208232      -0.270152      -1.315192 -0.704223 -0.395687
# 355     1.531629  1.408978       1.017350      -1.315192 -0.704223 -0.202940
#
#      DiabetesPedigreeFunction       Age  Outcome  BMI_category_Obese  \
# 446                  0.536640 -0.431718        0                 0.0
# 260                 -0.533988  0.082657        0                 1.0
# 570                 -0.620473  0.511303        0                 1.0
# 590                  1.332900  1.025678        1                 1.0
# 30                   0.202628  2.311616        0                 1.0
# ..                        ...       ...      ...                 ...
# 218                  2.224592 -0.088801        1                 0.0
# 223                  0.623125  2.397345        0                 0.0
# 271                 -1.043952 -1.031822        0                 0.0
# 474                 -1.049917 -0.774634        0                 0.0
# 355                 -0.525041  1.368595        1                 1.0
#
#      BMI_category_Overweight  BMI_category_Underweight
# 446                      1.0                       0.0
# 260                      0.0                       0.0
# 570                      0.0                       0.0
# 590                      0.0                       0.0
# 30                       0.0                       0.0
# ..                       ...                       ...
# 218                      1.0                       0.0
# 223                      1.0                       0.0
# 271                      1.0                       0.0
# 474                      1.0                       0.0
# 355                      0.0                       0.0
#
# [614 rows x 12 columns]

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()

# %%
X_train = train.drop(columns=['Outcome'])  # Features (exclude target)
y_train = train['Outcome']                # Target
X_val = val.drop(columns=['Outcome'])     # Validation features
y_val = val['Outcome']                    # Validation target

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(X_val)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_pred,y_val))
# Out:
# 0.7727272727272727

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score
max_depth_values = [3, 5, 7]
best_f1 = 0
best_depth = None
best_model = None

# Iterate through different max_depth values
for depth in max_depth_values:
    # Initialize Decision Tree model
    model = DecisionTreeClassifier(max_depth=depth, random_state=42)
    
    # Train the model
    model.fit(X_train, y_train)
    
    # Predict on validation data
    y_pred = model.predict(X_val)
    
    # Calculate F1 score
    f1 = f1_score(y_val, y_pred)
    print(f"Max Depth: {depth}, F1 Score: {f1:.4f}")
    
    # Update the best model if current F1 score is higher
    if f1 > best_f1:
        best_f1 = f1
        best_depth = depth
        best_model = model

print(f"\nBest Max Depth: {best_depth}, Best F1 Score: {best_f1:.4f}")

# Predict with the best model
y_best_pred = best_model.predict(X_val)

# Optional: Print the decision tree structure (requires `graphviz`)
from sklearn.tree import export_text
print("\nDecision Tree Structure:\n")
print(export_text(best_model, feature_names=list(X_train.columns)))
# Out:
# Max Depth: 3, F1 Score: 0.6598
# Max Depth: 5, F1 Score: 0.4490
# Max Depth: 7, F1 Score: 0.6154
#
# Best Max Depth: 3, Best F1 Score: 0.6598
#
# Decision Tree Structure:
#
# |--- Glucose <= 0.22
# |   |--- Age <= -0.39
# |   |   |--- BMI <= 1.72
# |   |   |   |--- class: 0
# |   |   |--- BMI >  1.72
# |   |   |   |--- class: 1
# |   |--- Age >  -0.39
# |   |   |--- BMI <= -0.65
# |   |   |   |--- class: 0
# |   |   |--- BMI >  -0.65
# |   |   |   |--- class: 0
# |--- Glucose >  0.22
# |   |--- BMI_category_Obese <= 0.50
# |   |   |--- Glucose <= 0.79
# |   |   |   |--- class: 0
# |   |   |--- Glucose >  0.79
# |   |   |   |--- class: 0
# |   |--- BMI_category_Obese >  0.50
# |   |   |--- Glucose <= 1.17
# |   |   |   |--- class: 1
# |   |   |--- Glucose >  1.17
# |   |   |   |--- class: 1
